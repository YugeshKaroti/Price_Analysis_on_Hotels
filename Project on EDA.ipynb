# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Hotels.csv")

# %%
df
# Out:
#                                       Hotel Name       City  \
# 0                         FabExpress Golden Gate  Hyderabad
# 1       Collection O Orange Tree Hotels Near DLF  Hyderabad
# 2                 Collection O 81504 Hotel Pride  Hyderabad
# 3     ibis Hyderabad Hitec City - An Accor Brand  Hyderabad
# 4                        Avana- A Boutique Hotel  Hyderabad
# ...                                          ...        ...
# 996                             FabHotel Culture      Noida
# 997                FabExpress F9 Noida Sector 27      Noida
# 998                        FabHotel F9 Sector 19      Noida
# 999                            FabExpress Ashray      Noida
# 1000          Itsy By Treebo - City Centre Noida      Noida
#
#       Distance from Centre (in km) Review (in words)  Number of Reviews  \
# 0                              6.5             Good                  82
# 1                              9.3         No Review                  0
# ...

# %%
sns.histplot(df["Distance from Centre (in km)"],kde=True,color="Blue")
plt.title("Histogram for Distance from Centre (in km) column")
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("ggplot")
sns.histplot(df["Rating (out of 10)"],kde=True,color="Red")
plt.title("Histogram for Rating (out of 10) column")
plt.show()

# %%
sns.histplot(df["Cost"],kde=True,color="green")
plt.title("Histogram for Cost column")
plt.show()

# %%
sns.histplot(df["Taxes and charges"],kde=True,color="Indigo")
plt.title("Histogram for Taxes and charges column")
plt.show()

# %%
df["City"].value_counts().plot.pie(autopct="%.2f")
plt.title("Pie chart for different cities")
plt.show()

# %%
df["Review (in words)"].value_counts().plot.bar(color=["red","green","orange","purple","blue","maroon","Indigo"])
plt.xlabel("Reviews")
plt.ylabel("Count")
plt.title("Bar plot for Reviews (in words) column")
plt.show()

# %%
df.columns
# Out:
# Index(['Hotel Name', 'City', 'Distance from Centre (in km)',
#        'Review (in words)', 'Number of Reviews', 'Rating (out of 10)',
#        'Level of sustainability', 'Type of Room', 'Type of Bed',
#        'Type of Cancellation', 'Cost', 'Taxes and charges', 'Type of Payment'],
#       dtype='object')

# %%
sns.countplot(x="Level of sustainability",data=df,width=0.3)
plt.title("Count plot for Level of sustainability column")
plt.show()

# %%
plt.style.use("ggplot")
sns.countplot(x="Type of Cancellation",data=df,width=0.3)
plt.title("Count plot for Type of Cancellation column")
plt.show()

# %%
sns.countplot(x="Type of Payment",data=df,width=0.2)
plt.title("Count plot for Type of Payment column")
plt.show()

# %%
plt.scatter(df["Rating (out of 10)"],df["Cost"],marker="*",color="blue")
plt.xlabel("Rating")
plt.ylabel("Price")
plt.title("Scatter plot for Rating and Cost")
plt.show()

# %%
data12=df[["Distance from Centre (in km)","Number of Reviews","Rating (out of 10)","Level of sustainability","Cost","Taxes and charges"]]

# %%
sns.heatmap(data12.corr(),annot=True)
plt.show()
