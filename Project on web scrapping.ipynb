# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# %%
path = r"C:\Users\yuges\Downloads\chromedriver.exe"

# %%
servise = Service(executable_path = path)

# %%
driver=webdriver.Chrome(service=servise)

# %% [markdown]
# #### Code for Hyderabad

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=Hyderabad&ssne=Hyderabad&ssne_untouched=Hyderabad&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2097701&dest_type=city&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\d+.?\d?\skm",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        b=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(b):
            Number_of_reviews.append(b.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="d7449d770c a081c98c6f"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        e=i.find("div",class_="abf093bdfe d068504c75")
        if(e):
            Free_Cancellation.append(e.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="Hyderabad"
for i in range(1,101):
    Location.append(city)

# %% [markdown]
# #### DataFrame for hotels in Hyderabad

# %%
dict1={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data=pd.DataFrame(data=dict1,index=[i for i in range(1,101)])

# %%
data=data.mask(data=='')

# %%
data.to_csv("Hyderabad.csv",index=None)

# %% [markdown]
# #### Code for Bangalore

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url1=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=Bangalore%2C+Karnataka%2C+India&ssne=Hyderabad&ssne_untouched=Hyderabad&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2090174&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=e2114340065e03b0&ac_meta=GhBlMjExNDM0MDA2NWUwM2IwIAAoATICZW46A2JhbkAASgBQAA%3D%3D&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url1)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("(\d+\s[km]+)",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(a):
            Number_of_reviews.append(a.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe d068504c75")
        if(a):
            Free_Cancellation.append(a.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="d7449d770c a081c98c6f"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="Bangalore"
for i in range(1,101):
    Location.append(city)

# %%
dict2={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data2=pd.DataFrame(data=dict2,index=[i for i in range(1,101)])

# %%
data2=data2.mask(data2=='') #To fill empty values with np.nan

# %%
data2.to_csv("Bangalore.csv",index=None)

# %% [markdown]
# #### Code for Mumbai

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url1=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=Mumbai%2C+Maharashtra%2C+India&ssne=Bangalore&ssne_untouched=Bangalore&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2092174&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=17c844c459e702cc&ac_meta=GhAxN2M4NDRjNDU5ZTcwMmNjIAAoATICZW46A211bUAASgBQAA%3D%3D&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url1)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("map(\d+.?\d?\s[mkm]+)",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(a):
            Number_of_reviews.append(a.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe d068504c75")
        if(a):
            Free_Cancellation.append(a.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="d7449d770c a081c98c6f"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="Mumbai"
for i in range(1,102):
    Location.append(city)

# %%
dict3={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data3=pd.DataFrame(data=dict3,index=[i for i in range(1,102)])

# %%
data3=data3.mask(data3=='') #To fill empty values with nan

# %%
data3.to_csv("Mumbai.csv",index=None)

# %% [markdown]
# #### Code for Chennai

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url3=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=Chennai%2C+Tamil+Nadu%2C+India&ssne=Mumbai&ssne_untouched=Mumbai&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=ChIJYTN9T-plUjoRM9RjaAunYW4&dest_type=city&place_id=ChIJYTN9T-plUjoRM9RjaAunYW4&latitude=13.0826802&longitude=80.2707184&ac_position=0&ac_click_type=g&ac_langcode=en-gb&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=df133faeedbf000a&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url3)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("map(\d?\.?\d+\s[mkm]+)",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        b=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(b):
            Number_of_reviews.append(b.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe d068504c75")
        if(a):
            Free_Cancellation.append(a.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="Chennai"
for i in range(1,101):
    Location.append(city)

# %%
dict4={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data4=pd.DataFrame(data=dict4,index=[i for i in range(1,101)])

# %%
data4=data4.mask(data4=='') #To remove empty values in data4

# %%
data4.to_csv("Chennai.csv",index=None)

# %% [markdown]
# #### Code for New Delhi

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url4=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=New+Delhi%2C+Delhi+NCR%2C+India&ssne=Chennai%2C+Tamil+Nadu%2C+India&ssne_untouched=Chennai%2C+Tamil+Nadu%2C+India&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2106102&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=506046b5b74400c4&ac_meta=GhA1MDYwNDZiNWI3NDQwMGM0IAAoATICZW46BWRlbGhpQABKAFAA&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url4)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\d+.?\d?\skm",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        b=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(b):
            Number_of_reviews.append(b.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe d068504c75")
        if(a):
            Free_Cancellation.append(a.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="New Delhi"
for i in range(1,101):
    Location.append(city)

# %%
dict5={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data5=pd.DataFrame(data=dict5,index=[i for i in range(1,101)])

# %%
data5=data5.mask(data5=='') #To fill empty values with np.nan

# %%
data5.to_csv("New Delhi.csv",index=None)

# %% [markdown]
# #### Code for Kochi

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url5=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=Cochin%2C+Kerala%2C+India&ssne=Hyderabad&ssne_untouched=Hyderabad&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2093645&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=3a554c08fb60008c&ac_meta=GhAzYTU1NGMwOGZiNjAwMDhjIAAoATICZW46BWtvY2hpQABKAFAA&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url5)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("map(\d+\.?\d?\s[kmm]+)",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        b=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(b):
            Number_of_reviews.append(b.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe d068504c75")
        if(a):
            Free_Cancellation.append(a.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="Kochi"
for i in range(1,101):
    Location.append(city)

# %%
dict6={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data6=pd.DataFrame(data=dict6,index=[i for i in range(1,101)])

# %%
data6=data6.mask(data6=='')

# %%
data6.to_csv("Kochi.csv",index=None)

# %% [markdown]
# #### Code for Kolkata

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url6=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=Kolkata%2C+West+Bengal%2C+India&ssne=Hyderabad&ssne_untouched=Hyderabad&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2092511&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=7ca029cff2d70024&ac_meta=GhA3Y2EwMjljZmYyZDcwMDI0IAAoATICZW46A2tvbEAASgBQAA%3D%3D&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url6)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("(\d?\.?\d\s[kmm]+)\sfrom",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        b=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(b):
            Number_of_reviews.append(b.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe d068504c75")
        if(a):
            Free_Cancellation.append(a.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="Kolkata"
for i in range(1,101):
    Location.append(city)

# %%
dict7={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data7=pd.DataFrame(data=dict7,index=[i for i in range(1,101)])

# %%
data7=data7.mask(data7=='') #To fill empty values with nan

# %%
data7.to_csv("Kolkata.csv",index=None)

# %% [markdown]
# #### Code for Pune

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url7=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=Pune%2C+Maharashtra%2C+India&ssne=Kolkata&ssne_untouched=Kolkata&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2108361&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=c8042c9cfcbe00b3&ac_meta=GhBjODA0MmM5Y2ZjYmUwMGIzIAAoATICZW46BHB1bmVAAEoAUAA%3D&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url7)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("(\d?\.?\d\s[kmm]+)\sfrom",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        b=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(b):
            Number_of_reviews.append(b.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe d068504c75")
        if(a):
            Free_Cancellation.append(a.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="Pune"
for i in range(1,102):
    Location.append(city)

# %%
dict8={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data8=pd.DataFrame(data=dict8,index=[i for i in range(1,102)])

# %%
data8=data8.mask(data8=='')

# %%
data8.to_csv("Pune.csv",index=None)

# %% [markdown]
# #### Code for Lucknow

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url8=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=Lucknow%2C+Uttar+Pradesh%2C+India&ssne=Pune&ssne_untouched=Pune&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2102835&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=da3f2f501360011e&ac_meta=GhBkYTNmMmY1MDEzNjAwMTFlIAAoATICZW46B2x1Y2tub3dAAEoAUAA%3D&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url8)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("(\d+\.?\d?\s[kmm]+)\sfrom",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        b=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(b):
            Number_of_reviews.append(b.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe d068504c75")
        if(a):
            Free_Cancellation.append(a.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="Lucknow"
for i in range(1,101):
    Location.append(city)

# %%
dict9={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data9=pd.DataFrame(data=dict9,index=[i for i in range(1,101)])

# %%
data9=data9.mask(data9=='')

# %%
data9.to_csv("Lucknow.csv",index=None)

# %% [markdown]
# #### Code for Noida

# %%
Hotel_name=[]
Location=[]
Distance_from_city=[]
Overall_review=[]
Number_of_reviews=[]
Overall_rating=[]
Sustainable_level=[]
Room_Type=[]
Bed_Type=[]
Free_Cancellation=[]
price=[]
Tax=[]
prepayment=[]
for i in range(1,100,25):
    url9=f"https://www.booking.com/searchresults.en-gb.html?label=msn-SvOYT_f6pES7XcBmICjudw-80401890429994%3Atikwd-17116145739%3Aaud-807859093%3Aloc-90%3Aneo%3Amte%3Alp158516%3Adec%3Aqshotels%2Bin%2Bmumbai&sid=af0d52358b8d524164a8d6d5aca460cb&aid=339462&ss=Noida%2C+Uttar+Pradesh%2C+India&ssne=Lucknow&ssne_untouched=Lucknow&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=900048213&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=d7283ebe9e6e03ca&ac_meta=GhBkNzI4M2ViZTllNmUwM2NhIAAoATICZW46BU5vaWRhQABKAFAA&checkin=2023-09-28&checkout=2023-09-29&group_adults=1&no_rooms=1&group_children=0&offset={i}"
    driver.get(url9)
    soup=BeautifulSoup(driver.page_source,"html.parser")
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="f6431b446c a23c043802")
        if(a):
            Hotel_name.append(a.text)
        else:
            Hotel_name.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("(\d+\.?\d?\s[kmm]+)\sfrom",text)
        if(regex):
            Distance_from_city.append(regex[0])
        else:
            Distance_from_city.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 e6208ee469 cb2cbb3ccb")
        if(a):
            Overall_review.append(a.text)
        else:
            Overall_review.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        b=i.find("div",class_="abf093bdfe f45d8e4c32 d935416c47")
        if(b):
            Number_of_reviews.append(b.text)
        else:
            Number_of_reviews.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="a3b8729ab1 d86cee9b25")
        if(a):
            Overall_rating.append(a.text)
        else:
            Overall_rating.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\s(Level\s\d)",text)
        if(regex):
            Sustainable_level.append(regex[0])
        else:
            Sustainable_level.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="df597226dd")
        if(a):
            Room_Type.append(a.text)
        else:
            Room_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="cb5b4b68a4")
        if(a):
            Bed_Type.append(a.text)
        else:
            Bed_Type.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("div",class_="abf093bdfe d068504c75")
        if(a):
            Free_Cancellation.append(a.text)
        else:
            Free_Cancellation.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        a=i.find("span",class_="f6431b446c fbd1d3018c e729ed5ab6")
        if(a):
            price.append(a.text)
        else:
            price.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("\+(₹\s\d+,?\d+)",text)
        if(regex):
            Tax.append(regex[0])
        else:
            Tax.append(np.nan)
    for i in soup.find_all("div",class_="b978843432"):
        text=i.text
        regex=re.findall("No\sprepayment\sneeded",text)
        if(regex):
            prepayment.append(regex[0])
        else:
            prepayment.append(np.nan)
city="Noida"
for i in range(1,101):
    Location.append(city)

# %%
dict10={"Hotel Name":Hotel_name,"City":Location,"Distance from City":Distance_from_city,"Review (in words)":Overall_review,"Number of Reviews":Number_of_reviews,"Rating (out of 10)":Overall_rating,"Level of sustainability":Sustainable_level,"Type of Room":Room_Type,"Number of Beds":Bed_Type,"Type of Cancellation":Free_Cancellation,"Cost":price,"Taxes and charges":Tax,"Type of Payment":prepayment}

# %%
data10=pd.DataFrame(data=dict10,index=[i for i in range(1,101)])

# %%
data10=data10.mask(data10=='')

# %%
data10.to_csv("Noida.csv",index=None)
